# %%
from ultralytics import YOLO
import cv2
import json
import os
from pathlib import Path
import numpy as np
from symspellpy import SymSpell, Verbosity
import re

# Настройка путей
model_path = "runs/detect/train/weights/best.pt"  # Путь к модели YOLO
images_dir = "301"  # Папка с изображениями
json_dir = "day1/school"  # Папка с JSON-файлами
save_folder = "result"  # Папка для результатов
dictionary_path = "russian.txt"  # Путь к словарю SymSpell
numbers = {'0': '22', '1': '23', '2': '24', '3': '25', '4': '26', '5': '27', '6': '28', 'none': 'none'}

# %%
# Функция для проверки, является ли строка словом
def is_word(s: str) -> bool:
    # Проверяет, что строка содержит только буквы кириллицы или дефисы и имеет хотя бы одну букву
    return bool(re.match(r'^[а-яА-Я\-]*[а-яА-Я][а-яА-Я\-]*$', s))

# Функция для объединения слов с дефисами
def merge_words(words: list[str]) -> list[str]:
    # Возвращает новый список, объединяя слова, где первое заканчивается на дефис
    result = []
    i = 0
    while i < len(words):
        if not is_word(words[i]):
            result.append(words[i])
            i += 1
            continue
        if words[i].endswith('-') and i + 1 < len(words) and is_word(words[i + 1]):
            merged_word = words[i][:-1] + words[i + 1]
            if is_word(merged_word):
                result.append(merged_word)
                i += 2  # Пропускаем два слова
            else:
                result.append(words[i])
                i += 1
        else:
            result.append(words[i])
            i += 1
    return result

# Функция для поиска исправленного слова с помощью SymSpell
def finder_symspell(word: str, sym_spell: SymSpell, max_edit_distance: int = 3) -> str:
    word_lower = word.lower()
    suggestions = sym_spell.lookup(word_lower, Verbosity.TOP, max_edit_distance=0)
    if suggestions:
        return word
    suggestions = sym_spell.lookup(word_lower, Verbosity.TOP, max_edit_distance)
    if suggestions:
        return suggestions[0].term
    return word_lower

# Функция для инициализации SymSpell
def init_symspell(path: str, max_edit_distance: int = 3) -> SymSpell:
    sym_spell = SymSpell(max_dictionary_edit_distance=max_edit_distance)
    try:
        with open(path, 'r', encoding='utf-8') as f:
            for word in f:
                word = word.rstrip()
                if is_word(word):
                    sym_spell.create_dictionary_entry(word, 1)
    except FileNotFoundError:
        print(f"Файл словаря {path} не найден")
        raise
    return sym_spell

# %%
# Функция для вычисления IoU
def calculate_iou(box1, box2):
    x1_min, y1_min, x1_max, y1_max = box1  # JSON box
    x2_min, y2_min, x2_max, y2_max = box2  # YOLO box
    
    x_left = max(x1_min, x2_min)
    y_top = max(y1_min, y2_min)
    x_right = min(x1_max, x2_max)
    y_bottom = min(y1_max, y2_max)
    
    if x_right < x_left or y_bottom < y_top:
        return 0.0
    
    intersection = (x_right - x_left) * (y_bottom - y_top)
    area1 = (x1_max - x1_min) * (y1_max - y1_min)  # JSON box area
    area2 = (x2_max - x2_min) * (y2_max - y2_min)  # YOLO box area
    union = area1 + area2 - intersection
    
    iou = intersection / union if union > 0 else 0.0
    return iou

# Функция для загрузки JSON
def load_json(json_path):
    try:
        with open(json_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
        return data
    except Exception as e:
        print(f"Ошибка при загрузке {json_path}: {e}")
        return None

def extract_text_from_json(json_data, sym_spell):
    texts = []
    raw_words = []

    if not json_data or not isinstance(json_data, dict):
        return texts

    data = json_data.get("data")
    if not data or not isinstance(data, dict):
        return texts

    blocks = data.get("blocks")
    if not blocks or not isinstance(blocks, list):
        return texts

    # Извлечение слов и их координат
    for block in blocks:
        boxes = block.get("boxes")
        if not boxes or not isinstance(boxes, list):
            continue

        for box in boxes:
            languages = box.get("languages")
            if not languages or not isinstance(languages, list):
                continue

            for lang in languages:
                texts_list = lang.get("texts")
                if not texts_list or not isinstance(texts_list, list):
                    continue

                for text in texts_list:
                    words = text.get("words")
                    if not words or not isinstance(words, list):
                        continue

                    for word in words:
                        word_text = word.get("word", "")
                        x = word.get("x", 0)
                        y = word.get("y", 0)
                        w = word.get("w", 0)
                        h = word.get("h", 0)
                        raw_words.append(word_text)
                        texts.append({
                            "text": word_text,
                            "bbox": [x, y, x + w, y + h]
                        })

    if not texts:
        return texts

    # Объединение слов с дефисами
    merged_words = merge_words(raw_words)

    # Исправление слов с помощью SymSpell
    corrected_words = [finder_symspell(word, sym_spell) for word in merged_words]

    # Обновление текста в списке texts
    corrected_index = 0
    for i, text_item in enumerate(texts):
        if corrected_index < len(corrected_words):
            texts[i]["text"] = corrected_words[corrected_index]
            if (
                i + 1 < len(raw_words)
                and raw_words[i].endswith("-")
                and is_word(raw_words[i + 1])
            ):
                corrected_index += 1  # Пропустить объединённое слово
            corrected_index += 1

    return texts

# %%
try:
    sym_spell = init_symspell(dictionary_path)
except FileNotFoundError as e:
    print(f"Не удалось инициализировать SymSpell: {e}")
    raise

# %%
# Загрузка модели YOLO
os.makedirs(save_folder, exist_ok=True)
model = YOLO(model_path)
excluded_classes = [7, 8]  # Классы для исключения


# Проход по JSON-файлам
for json_file in Path(json_dir).glob("*res.json"):
    json_name = json_file.stem  # Имя JSON без расширения (например, 1119273396_03__1_res)
    img_name = json_name.split("__")[0]  # Извлекаем префикс (например, 1119273396_03)
    img_file = Path(images_dir) / f"{img_name}.png"
    output_file = Path(save_folder) / f"{json_name}.txt"  # Файл результата
    
    if not img_file.exists():
        print(f"Изображение для {json_name} не найдено: {img_file}")
        with open(output_file, 'w', encoding='utf-8') as f:
            f.write(f"Изображение {img_name}.png не найдено\n")
        continue
    
    # Чтение JSON
    json_data = load_json(json_file)
    if json_data is None:
        print(f"Пропуск {json_name} из-за ошибки загрузки JSON")
        continue
    
    json_texts = extract_text_from_json(json_data, sym_spell)
    if not json_texts:
        print(f"В {json_name} не найдены тексты")
        with open(output_file, 'w', encoding='utf-8') as f:
            f.write("Нет текстов в JSON\n")
        continue
    
    # Получение предсказаний YOLO для изображения
    try:
        results = model.predict(source=str(img_file), imgsz=640, save=False, conf=0.3)
        result = results[0]  # Предполагаем, что одно изображение
    except Exception as e:
        print(f"Ошибка YOLO для {img_name}: {e}")
        with open(output_file, 'w', encoding='utf-8') as f:
            for json_text in json_texts:
                f.write(f"Text: {json_text['text']}, Number: none, Bbox: none, Confidence: none\n")
            f.write(f"Ошибка YOLO: {e}\n")
        continue
    
    # Получение предсказаний
    bboxes = result.boxes.xyxy.cpu().numpy()  # [x_min, y_min, x_max, y_max]
    classes = result.boxes.cls.cpu().numpy()  # Метки классов
    confidences = result.boxes.conf.cpu().numpy()  # Вероятности
    
    # Фильтрация исключённых классов
    valid_indices = [i for i, cls in enumerate(classes) if cls not in excluded_classes]
    bboxes = bboxes[valid_indices]
    classes = classes[valid_indices]
    confidences = confidences[valid_indices]
    
    # Сопоставление текста с номерами
    matches = []
    for json_text in json_texts:
        json_bbox = json_text["bbox"]
        best_iou = 0.0
        best_conf = 0.0
        best_number = "none"
        best_bbox = "none"
        
        for i, bbox in enumerate(bboxes):
            iou = calculate_iou(json_bbox, bbox)
            if iou > best_iou or (iou == best_iou and confidences[i] > best_conf):  # Выбираем бокс с максимальным IoU или максимальной уверенностью
                best_iou = iou
                best_conf = confidences[i]
                best_number = str(int(classes[i]))
                best_bbox = bbox.tolist()
        
        
        conf_str = f"{best_conf:.2f}" if best_conf > 0 else "none"
        matches.append(f"Text: {json_text['text']}, Number: {numbers[best_number]}, Confidence: {conf_str}, Bbox: {best_bbox}")
    
    # Сохранение результатов в файл
    try:
        with open(output_file, 'w', encoding='utf-8') as f:
            for line in matches:
                f.write(line + "\n")
        print(f"Результаты для {json_name} сохранены в {output_file}")
    except Exception as e:
        print(f"Ошибка записи в файл {output_file}: {e}")
        continue
# Out:
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1119273396_03.png: 640x576 1 22, 1 24, 1 номер, 33.5ms
# Speed: 2.6ms preprocess, 33.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1119273396_03__1_res сохранены в result/1119273396_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220092805_03.png: 640x576 1 28, 37.2ms
# Speed: 1.7ms preprocess, 37.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220092805_03__1_res сохранены в result/2220092805_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820718380_02.png: 640x576 1 24, 1 номер, 31.2ms
# Speed: 1.9ms preprocess, 31.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820718380_02__1_res сохранены в result/2820718380_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720854136_04.png: 640x576 1 24, 1 номер, 32.4ms
# Speed: 1.7ms preprocess, 32.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720854136_04__1_res сохранены в result/2720854136_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2721879774_04.png: 640x576 2 27s, 1 28, 33.1ms
# Speed: 1.7ms preprocess, 33.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2721879774_04__1_res сохранены в result/2721879774_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1119312714_06.png: 640x576 (no detections), 47.3ms
# Speed: 15.4ms preprocess, 47.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1119312714_06__1_res сохранены в result/1119312714_06__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1119313834_04.png: 640x576 1 22, 1 номер, 37.5ms
# Speed: 1.7ms preprocess, 37.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1119313834_04__1_res сохранены в result/1119313834_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220182657_03.png: 640x576 1 24, 1 28, 40.0ms
# Speed: 1.9ms preprocess, 40.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220182657_03__1_res сохранены в result/2220182657_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220200974_02.png: 640x576 1 22, 1 24, 3 номерs, 37.9ms
# Speed: 1.9ms preprocess, 37.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220200974_02__1_res сохранены в result/2220200974_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1120340046_03.png: 640x576 1 номер, 36.4ms
# Speed: 1.9ms preprocess, 36.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1120340046_03__1_res сохранены в result/1120340046_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220175109_02.png: 640x576 1 24, 37.1ms
# Speed: 1.7ms preprocess, 37.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220175109_02__1_res сохранены в result/2220175109_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220192253_07.png: 640x576 1 24, 37.0ms
# Speed: 1.8ms preprocess, 37.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220192253_07__1_res сохранены в result/2220192253_07__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2223594675_04.png: 640x576 1 28, 38.5ms
# Speed: 1.8ms preprocess, 38.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2223594675_04__1_res сохранены в result/2223594675_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720858258_02.png: 640x576 1 22, 36.9ms
# Speed: 1.8ms preprocess, 36.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720858258_02__1_res сохранены в result/2720858258_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820729299_02.png: 640x576 2 22s, 2 номерs, 38.0ms
# Speed: 1.7ms preprocess, 38.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820729299_02__1_res сохранены в result/2820729299_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1920295824_02.png: 640x576 1 22, 1 24, 1 25, 2 номерs, 33.4ms
# Speed: 1.8ms preprocess, 33.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1920295824_02__1_res сохранены в result/1920295824_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2420026872_03.png: 640x576 1 22, 37.7ms
# Speed: 1.7ms preprocess, 37.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2420026872_03__1_res сохранены в result/2420026872_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220097377_05.png: 640x576 1 28, 35.9ms
# Speed: 1.7ms preprocess, 35.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220097377_05__1_res сохранены в result/2220097377_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2719814415_04.png: 640x576 2 28s, 1 номер, 34.2ms
# Speed: 2.1ms preprocess, 34.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2719814415_04__1_res сохранены в result/2719814415_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220193998_05.png: 640x576 1 22, 2 28s, 1 номер, 35.4ms
# Speed: 1.8ms preprocess, 35.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220193998_05__1_res сохранены в result/2220193998_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1119307734_03.png: 640x576 1 28, 36.1ms
# Speed: 1.7ms preprocess, 36.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1119307734_03__1_res сохранены в result/1119307734_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2921008493_07.png: 640x576 1 22, 1 24, 1 номер, 37.2ms
# Speed: 1.8ms preprocess, 37.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2921008493_07__1_res сохранены в result/2921008493_07__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2420026330_04.png: 640x576 1 22, 1 номер, 33.9ms
# Speed: 1.7ms preprocess, 33.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2420026330_04__1_res сохранены в result/2420026330_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220206770_04.png: 640x576 1 22, 1 номер, 34.7ms
# Speed: 2.1ms preprocess, 34.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220206770_04__1_res сохранены в result/2220206770_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2419998278_04.png: 640x576 1 23, 2 25s, 34.2ms
# Speed: 1.7ms preprocess, 34.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2419998278_04__1_res сохранены в result/2419998278_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820747487_07.png: 640x576 2 24s, 1 номер, 35.1ms
# Speed: 1.7ms preprocess, 35.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820747487_07__1_res сохранены в result/2820747487_07__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820748417_05.png: 640x576 1 28, 1 номер, 35.3ms
# Speed: 1.6ms preprocess, 35.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820748417_05__1_res сохранены в result/2820748417_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1120350621_03.png: 640x576 1 28, 33.1ms
# Speed: 1.7ms preprocess, 33.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1120350621_03__1_res сохранены в result/1120350621_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1120326171_04.png: 640x576 2 22s, 1 номер, 34.8ms
# Speed: 1.9ms preprocess, 34.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1120326171_04__1_res сохранены в result/1120326171_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820728695_04.png: 640x576 1 22, 1 23, 33.3ms
# Speed: 2.0ms preprocess, 33.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820728695_04__1_res сохранены в result/2820728695_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2819703472_06.png: 640x576 1 23, 1 24, 34.5ms
# Speed: 1.7ms preprocess, 34.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2819703472_06__1_res сохранены в result/2819703472_06__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220204932_06.png: 640x576 1 28, 32.5ms
# Speed: 1.7ms preprocess, 32.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220204932_06__1_res сохранены в result/2220204932_06__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220105918_02.png: 640x576 1 24, 33.8ms
# Speed: 1.7ms preprocess, 33.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220105918_02__1_res сохранены в result/2220105918_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2420005152_04.png: 640x576 1 22, 1 25, 36.7ms
# Speed: 1.7ms preprocess, 36.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2420005152_04__1_res сохранены в result/2420005152_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2719812198_02.png: 640x576 1 23, 1 24, 34.5ms
# Speed: 2.1ms preprocess, 34.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2719812198_02__1_res сохранены в result/2719812198_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2719825083_02.png: 640x576 4 22s, 1 23, 1 24, 2 номерs, 37.8ms
# Speed: 1.8ms preprocess, 37.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2719825083_02__1_res сохранены в result/2719825083_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2719814331_07.png: 640x576 1 22, 34.8ms
# Speed: 1.9ms preprocess, 34.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2719814331_07__1_res сохранены в result/2719814331_07__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1420882361_02.png: 640x576 1 27, 1 28, 2 номерs, 33.5ms
# Speed: 1.9ms preprocess, 33.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1420882361_02__1_res сохранены в result/1420882361_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820749303_02.png: 640x576 1 22, 2 номерs, 32.9ms
# Speed: 1.7ms preprocess, 32.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820749303_02__1_res сохранены в result/2820749303_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220154421_04.png: 640x576 (no detections), 33.9ms
# Speed: 1.9ms preprocess, 33.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220154421_04__1_res сохранены в result/2220154421_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1119318375_04.png: 640x576 2 28s, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1119318375_04__1_res сохранены в result/1119318375_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220228189_03.png: 640x576 (no detections), 34.0ms
# Speed: 1.7ms preprocess, 34.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220228189_03__1_res сохранены в result/2220228189_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720834356_05.png: 640x576 1 28, 36.8ms
# Speed: 1.8ms preprocess, 36.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720834356_05__1_res сохранены в result/2720834356_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720833057_04.png: 640x576 1 28, 34.4ms
# Speed: 1.7ms preprocess, 34.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720833057_04__1_res сохранены в result/2720833057_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220212998_06.png: 640x576 1 24, 1 25, 33.8ms
# Speed: 1.9ms preprocess, 33.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220212998_06__1_res сохранены в result/2220212998_06__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2719812179_04.png: 640x576 (no detections), 32.8ms
# Speed: 1.6ms preprocess, 32.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2719812179_04__1_res сохранены в result/2719812179_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1120322733_07.png: 640x576 (no detections), 33.7ms
# Speed: 1.8ms preprocess, 33.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1120322733_07__1_res сохранены в result/1120322733_07__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720832000_06.png: 640x576 1 28, 37.4ms
# Speed: 2.0ms preprocess, 37.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720832000_06__1_res сохранены в result/2720832000_06__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220184268_04.png: 640x576 2 22s, 1 28, 1 номер, 33.8ms
# Speed: 1.8ms preprocess, 33.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220184268_04__1_res сохранены в result/2220184268_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220169632_02.png: 640x576 1 22, 1 24, 2 номерs, 35.3ms
# Speed: 1.8ms preprocess, 35.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220169632_02__1_res сохранены в result/2220169632_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2719812559_03.png: 640x576 1 28, 35.7ms
# Speed: 1.8ms preprocess, 35.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2719812559_03__1_res сохранены в result/2719812559_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220135069_03.png: 640x576 (no detections), 34.0ms
# Speed: 1.8ms preprocess, 34.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220135069_03__1_res сохранены в result/2220135069_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1120351624_05.png: 640x576 1 28, 34.0ms
# Speed: 1.8ms preprocess, 34.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1120351624_05__1_res сохранены в result/1120351624_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1423156826_02.png: 640x576 1 22, 3 номерs, 33.7ms
# Speed: 1.7ms preprocess, 33.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1423156826_02__1_res сохранены в result/1423156826_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220142244_04.png: 640x576 1 28, 33.7ms
# Speed: 1.7ms preprocess, 33.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220142244_04__1_res сохранены в result/2220142244_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2420011810_05.png: 640x576 1 28, 35.4ms
# Speed: 1.8ms preprocess, 35.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2420011810_05__1_res сохранены в result/2420011810_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1119267419_03.png: 640x576 1 номер, 38.0ms
# Speed: 1.8ms preprocess, 38.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1119267419_03__1_res сохранены в result/1119267419_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820722961_03.png: 640x576 2 22s, 2 номерs, 35.6ms
# Speed: 1.9ms preprocess, 35.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820722961_03__1_res сохранены в result/2820722961_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2420024624_04.png: 640x576 1 номер, 33.4ms
# Speed: 1.9ms preprocess, 33.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2420024624_04__1_res сохранены в result/2420024624_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1820710996_03.png: 640x576 2 27s, 1 28, 32.5ms
# Speed: 1.7ms preprocess, 32.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1820710996_03__1_res сохранены в result/1820710996_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720837316_02.png: 640x576 1 22, 1 24, 2 номерs, 32.6ms
# Speed: 1.9ms preprocess, 32.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720837316_02__1_res сохранены в result/2720837316_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2920989224_08.png: 640x576 1 24, 1 25, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2920989224_08__1_res сохранены в result/2920989224_08__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820720456_05.png: 640x576 2 28s, 34.8ms
# Speed: 1.6ms preprocess, 34.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820720456_05__1_res сохранены в result/2820720456_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2223670527_02.png: 640x576 1 22, 1 номер, 32.6ms
# Speed: 1.8ms preprocess, 32.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2223670527_02__1_res сохранены в result/2223670527_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220094308_03.png: 640x576 1 24, 31.5ms
# Speed: 1.9ms preprocess, 31.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220094308_03__1_res сохранены в result/2220094308_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220246037_06.png: 640x576 (no detections), 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220246037_06__1_res сохранены в result/2220246037_06__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2420013527_03.png: 640x576 1 22, 1 23, 3 номерs, 33.3ms
# Speed: 1.6ms preprocess, 33.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2420013527_03__1_res сохранены в result/2420013527_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220167554_02.png: 640x576 1 25, 2 номерs, 33.3ms
# Speed: 1.9ms preprocess, 33.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220167554_02__1_res сохранены в result/2220167554_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2719818519_03.png: 640x576 1 22, 3 номерs, 32.8ms
# Speed: 1.6ms preprocess, 32.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2719818519_03__1_res сохранены в result/2719818519_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1920297439_03.png: 640x576 1 22, 2 номерs, 33.6ms
# Speed: 1.9ms preprocess, 33.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1920297439_03__1_res сохранены в result/1920297439_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2420012116_07.png: 640x576 1 28, 1 номер, 33.8ms
# Speed: 1.7ms preprocess, 33.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2420012116_07__1_res сохранены в result/2420012116_07__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1120346087_04.png: 640x576 1 номер, 33.4ms
# Speed: 1.6ms preprocess, 33.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1120346087_04__1_res сохранены в result/1120346087_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220152100_03.png: 640x576 (no detections), 33.3ms
# Speed: 1.7ms preprocess, 33.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220152100_03__1_res сохранены в result/2220152100_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220143890_03.png: 640x576 1 22, 3 номерs, 34.7ms
# Speed: 1.9ms preprocess, 34.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220143890_03__1_res сохранены в result/2220143890_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220217309_03.png: 640x576 1 22, 1 25, 1 номер, 32.0ms
# Speed: 1.8ms preprocess, 32.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220217309_03__1_res сохранены в result/2220217309_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720839625_07.png: 640x576 1 24, 33.3ms
# Speed: 1.6ms preprocess, 33.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720839625_07__1_res сохранены в result/2720839625_07__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2819688928_04.png: 640x576 2 22s, 2 номерs, 32.6ms
# Speed: 1.7ms preprocess, 32.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2819688928_04__1_res сохранены в result/2819688928_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220125102_02.png: 640x576 1 номер, 32.9ms
# Speed: 1.7ms preprocess, 32.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220125102_02__1_res сохранены в result/2220125102_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2719826797_03.png: 640x576 1 28, 33.9ms
# Speed: 1.9ms preprocess, 33.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2719826797_03__1_res сохранены в result/2719826797_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2420023476_02.png: 640x576 1 номер, 32.0ms
# Speed: 1.9ms preprocess, 32.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2420023476_02__1_res сохранены в result/2420023476_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820711227_04.png: 640x576 1 номер, 32.2ms
# Speed: 2.0ms preprocess, 32.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820711227_04__1_res сохранены в result/2820711227_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220145045_03.png: 640x576 2 22s, 1 24, 1 номер, 36.0ms
# Speed: 1.7ms preprocess, 36.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220145045_03__1_res сохранены в result/2220145045_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220253274_07.png: 640x576 1 22, 1 23, 35.4ms
# Speed: 1.7ms preprocess, 35.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220253274_07__1_res сохранены в result/2220253274_07__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2420005454_02.png: 640x576 1 22, 1 24, 1 номер, 33.3ms
# Speed: 1.6ms preprocess, 33.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2420005454_02__1_res сохранены в result/2420005454_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2619412049_03.png: 640x576 1 28, 1 номер, 33.1ms
# Speed: 1.6ms preprocess, 33.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2619412049_03__1_res сохранены в result/2619412049_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1120339354_02.png: 640x576 1 22, 1 24, 2 номерs, 33.0ms
# Speed: 1.6ms preprocess, 33.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1120339354_02__1_res сохранены в result/1120339354_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820723699_03.png: 640x576 2 22s, 1 23, 1 24, 2 номерs, 32.4ms
# Speed: 1.9ms preprocess, 32.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820723699_03__1_res сохранены в result/2820723699_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2420015713_03.png: 640x576 (no detections), 32.3ms
# Speed: 1.7ms preprocess, 32.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2420015713_03__1_res сохранены в result/2420015713_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820720587_04.png: 640x576 1 28, 33.7ms
# Speed: 1.7ms preprocess, 33.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820720587_04__1_res сохранены в result/2820720587_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220188473_07.png: 640x576 1 24, 33.7ms
# Speed: 1.7ms preprocess, 33.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220188473_07__1_res сохранены в result/2220188473_07__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2419988913_03.png: 640x576 1 22, 1 23, 1 24, 1 номер, 34.3ms
# Speed: 2.2ms preprocess, 34.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2419988913_03__1_res сохранены в result/2419988913_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720836745_03.png: 640x576 1 28, 1 номер, 34.3ms
# Speed: 1.8ms preprocess, 34.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720836745_03__1_res сохранены в result/2720836745_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2719810982_06.png: 640x576 1 25, 34.1ms
# Speed: 1.7ms preprocess, 34.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2719810982_06__1_res сохранены в result/2719810982_06__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220139703_06.png: 640x576 2 22s, 32.1ms
# Speed: 1.8ms preprocess, 32.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220139703_06__1_res сохранены в result/2220139703_06__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1820693140_03.png: 640x576 1 28, 33.3ms
# Speed: 1.7ms preprocess, 33.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1820693140_03__1_res сохранены в result/1820693140_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2420022413_02.png: 640x576 3 28s, 32.4ms
# Speed: 1.8ms preprocess, 32.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2420022413_02__1_res сохранены в result/2420022413_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1119300154_02.png: 640x576 1 22, 3 номерs, 32.5ms
# Speed: 1.8ms preprocess, 32.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1119300154_02__1_res сохранены в result/1119300154_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2719827219_05.png: 640x576 1 22, 1 24, 2 номерs, 32.9ms
# Speed: 1.8ms preprocess, 32.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2719827219_05__1_res сохранены в result/2719827219_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220258379_03.png: 640x576 1 22, 1 23, 2 24s, 2 номерs, 33.2ms
# Speed: 1.8ms preprocess, 33.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220258379_03__1_res сохранены в result/2220258379_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720838164_04.png: 640x576 1 27, 1 28, 1 номер, 33.1ms
# Speed: 1.7ms preprocess, 33.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720838164_04__1_res сохранены в result/2720838164_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220145335_04.png: 640x576 1 22, 1 24, 1 номер, 32.8ms
# Speed: 1.9ms preprocess, 32.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220145335_04__1_res сохранены в result/2220145335_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1119299987_02.png: 640x576 1 22, 1 24, 2 номерs, 34.2ms
# Speed: 1.9ms preprocess, 34.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1119299987_02__1_res сохранены в result/1119299987_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220245972_06.png: 640x576 1 28, 32.7ms
# Speed: 1.7ms preprocess, 32.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220245972_06__1_res сохранены в result/2220245972_06__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220139088_02.png: 640x576 1 24, 2 номерs, 34.1ms
# Speed: 1.9ms preprocess, 34.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220139088_02__1_res сохранены в result/2220139088_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1119295779_03.png: 640x576 1 22, 1 23, 1 24, 32.9ms
# Speed: 1.8ms preprocess, 32.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1119295779_03__1_res сохранены в result/1119295779_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220188846_02.png: 640x576 1 22, 2 номерs, 33.1ms
# Speed: 1.7ms preprocess, 33.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220188846_02__1_res сохранены в result/2220188846_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1120318845_03.png: 640x576 1 28, 33.3ms
# Speed: 1.6ms preprocess, 33.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1120318845_03__1_res сохранены в result/1120318845_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2819689349_04.png: 640x576 1 номер, 32.6ms
# Speed: 1.7ms preprocess, 32.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2819689349_04__1_res сохранены в result/2819689349_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2819707496_06.png: 640x576 1 28, 32.1ms
# Speed: 1.7ms preprocess, 32.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2819707496_06__1_res сохранены в result/2819707496_06__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220140951_02.png: 640x576 (no detections), 35.6ms
# Speed: 1.5ms preprocess, 35.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220140951_02__1_res сохранены в result/2220140951_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220189556_05.png: 640x576 1 22, 1 номер, 35.6ms
# Speed: 1.7ms preprocess, 35.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220189556_05__1_res сохранены в result/2220189556_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820727701_06.png: 640x576 2 28s, 34.1ms
# Speed: 2.1ms preprocess, 34.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820727701_06__1_res сохранены в result/2820727701_06__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2419979621_03.png: 640x576 1 22, 2 23s, 34.8ms
# Speed: 1.7ms preprocess, 34.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2419979621_03__1_res сохранены в result/2419979621_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720833611_04.png: 640x576 1 22, 32.0ms
# Speed: 1.9ms preprocess, 32.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720833611_04__1_res сохранены в result/2720833611_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2420001119_03.png: 640x576 (no detections), 33.1ms
# Speed: 1.7ms preprocess, 33.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2420001119_03__1_res сохранены в result/2420001119_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220199865_04.png: 640x576 1 28, 32.2ms
# Speed: 2.0ms preprocess, 32.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220199865_04__1_res сохранены в result/2220199865_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220147030_03.png: 640x576 1 22, 1 номер, 35.2ms
# Speed: 1.7ms preprocess, 35.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220147030_03__1_res сохранены в result/2220147030_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820760142_02.png: 640x576 2 22s, 1 27, 1 номер, 33.0ms
# Speed: 1.7ms preprocess, 33.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820760142_02__1_res сохранены в result/2820760142_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2420004255_03.png: 640x576 1 27, 2 28s, 34.0ms
# Speed: 1.7ms preprocess, 34.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2420004255_03__1_res сохранены в result/2420004255_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1120320286_05.png: 640x576 2 22s, 2 23s, 2 номерs, 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1120320286_05__1_res сохранены в result/1120320286_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220182615_04.png: 640x576 1 22, 33.0ms
# Speed: 1.7ms preprocess, 33.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220182615_04__1_res сохранены в result/2220182615_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2419992687_05.png: 640x576 1 номер, 34.3ms
# Speed: 1.8ms preprocess, 34.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2419992687_05__1_res сохранены в result/2419992687_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1119308330_04.png: 640x576 (no detections), 36.6ms
# Speed: 1.8ms preprocess, 36.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1119308330_04__1_res сохранены в result/1119308330_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220094627_02.png: 640x576 2 22s, 1 23, 1 24, 2 номерs, 33.3ms
# Speed: 1.6ms preprocess, 33.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220094627_02__1_res сохранены в result/2220094627_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720846349_04.png: 640x576 1 22, 2 24s, 2 номерs, 34.8ms
# Speed: 1.6ms preprocess, 34.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720846349_04__1_res сохранены в result/2720846349_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720850518_03.png: 640x576 1 22, 1 28, 35.3ms
# Speed: 1.8ms preprocess, 35.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720850518_03__1_res сохранены в result/2720850518_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2419974692_03.png: 640x576 (no detections), 35.0ms
# Speed: 1.7ms preprocess, 35.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2419974692_03__1_res сохранены в result/2419974692_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1120340580_04.png: 640x576 1 22, 1 24, 1 номер, 32.6ms
# Speed: 1.8ms preprocess, 32.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1120340580_04__1_res сохранены в result/1120340580_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820721594_04.png: 640x576 2 28s, 1 номер, 34.8ms
# Speed: 1.8ms preprocess, 34.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820721594_04__1_res сохранены в result/2820721594_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1119300273_02.png: 640x576 (no detections), 35.0ms
# Speed: 1.7ms preprocess, 35.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1119300273_02__1_res сохранены в result/1119300273_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1119301070_05.png: 640x576 1 28, 34.6ms
# Speed: 1.7ms preprocess, 34.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1119301070_05__1_res сохранены в result/1119301070_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720843549_05.png: 640x576 3 28s, 39.1ms
# Speed: 2.5ms preprocess, 39.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720843549_05__1_res сохранены в result/2720843549_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1120326489_07.png: 640x576 1 25, 38.7ms
# Speed: 1.7ms preprocess, 38.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1120326489_07__1_res сохранены в result/1120326489_07__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1120338671_05.png: 640x576 1 28, 37.4ms
# Speed: 2.1ms preprocess, 37.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1120338671_05__1_res сохранены в result/1120338671_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220122738_07.png: 640x576 1 28, 35.0ms
# Speed: 1.7ms preprocess, 35.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220122738_07__1_res сохранены в result/2220122738_07__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220188567_04.png: 640x576 1 24, 1 28, 1 номер, 35.6ms
# Speed: 1.6ms preprocess, 35.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220188567_04__1_res сохранены в result/2220188567_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220220644_04.png: 640x576 1 номер, 34.9ms
# Speed: 1.9ms preprocess, 34.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220220644_04__1_res сохранены в result/2220220644_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720842649_02.png: 640x576 1 22, 1 23, 3 24s, 33.8ms
# Speed: 2.6ms preprocess, 33.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720842649_02__1_res сохранены в result/2720842649_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2420011243_02.png: 640x576 2 22s, 3 номерs, 32.6ms
# Speed: 1.8ms preprocess, 32.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2420011243_02__1_res сохранены в result/2420011243_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1120335106_05.png: 640x576 2 22s, 1 24, 1 номер, 40.4ms
# Speed: 2.2ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1120335106_05__1_res сохранены в result/1120335106_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2719810076_04.png: 640x576 1 22, 1 24, 38.4ms
# Speed: 1.9ms preprocess, 38.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2719810076_04__1_res сохранены в result/2719810076_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2221272740_02.png: 640x576 1 28, 40.4ms
# Speed: 1.8ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2221272740_02__1_res сохранены в result/2221272740_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220085295_02.png: 640x576 1 28, 1 номер, 39.5ms
# Speed: 2.0ms preprocess, 39.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220085295_02__1_res сохранены в result/2220085295_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220137464_03.png: 640x576 1 24, 38.1ms
# Speed: 2.0ms preprocess, 38.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220137464_03__1_res сохранены в result/2220137464_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1119276726_02.png: 640x576 1 номер, 38.6ms
# Speed: 1.9ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1119276726_02__1_res сохранены в result/1119276726_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1119306350_03.png: 640x576 1 24, 1 номер, 36.4ms
# Speed: 1.7ms preprocess, 36.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1119306350_03__1_res сохранены в result/1119306350_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220157661_07.png: 640x576 1 22, 1 24, 37.2ms
# Speed: 2.3ms preprocess, 37.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220157661_07__1_res сохранены в result/2220157661_07__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2819700718_02.png: 640x576 1 28, 1 номер, 33.7ms
# Speed: 1.8ms preprocess, 33.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2819700718_02__1_res сохранены в result/2819700718_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1120358384_06.png: 640x576 1 28, 38.6ms
# Speed: 2.0ms preprocess, 38.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1120358384_06__1_res сохранены в result/1120358384_06__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820731400_05.png: 640x576 1 22, 1 номер, 37.0ms
# Speed: 1.7ms preprocess, 37.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820731400_05__1_res сохранены в result/2820731400_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820728513_06.png: 640x576 1 24, 1 28, 37.0ms
# Speed: 1.8ms preprocess, 37.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820728513_06__1_res сохранены в result/2820728513_06__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2819694002_08.png: 640x576 1 24, 1 25, 37.6ms
# Speed: 1.7ms preprocess, 37.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2819694002_08__1_res сохранены в result/2819694002_08__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1720765519_03.png: 640x576 1 24, 34.6ms
# Speed: 1.9ms preprocess, 34.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1720765519_03__1_res сохранены в result/1720765519_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2819694932_04.png: 640x576 1 27, 1 28, 33.1ms
# Speed: 1.9ms preprocess, 33.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2819694932_04__1_res сохранены в result/2819694932_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220190470_04.png: 640x576 1 28, 1 номер, 33.6ms
# Speed: 1.7ms preprocess, 33.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220190470_04__1_res сохранены в result/2220190470_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220219877_02.png: 640x576 3 номерs, 35.4ms
# Speed: 1.8ms preprocess, 35.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220219877_02__1_res сохранены в result/2220219877_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220200121_04.png: 640x576 2 22s, 1 23, 1 номер, 34.4ms
# Speed: 1.7ms preprocess, 34.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220200121_04__1_res сохранены в result/2220200121_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820715308_05.png: 640x576 2 28s, 1 номер, 33.2ms
# Speed: 1.7ms preprocess, 33.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820715308_05__1_res сохранены в result/2820715308_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2921002971_02.png: 640x576 1 22, 2 номерs, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2921002971_02__1_res сохранены в result/2921002971_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2721922393_05.png: 640x576 1 28, 34.6ms
# Speed: 1.8ms preprocess, 34.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2721922393_05__1_res сохранены в result/2721922393_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220204209_08.png: 640x576 1 28, 33.8ms
# Speed: 1.8ms preprocess, 33.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220204209_08__1_res сохранены в result/2220204209_08__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720832298_04.png: 640x576 1 28, 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720832298_04__1_res сохранены в result/2720832298_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2420006086_05.png: 640x576 1 22, 34.5ms
# Speed: 1.7ms preprocess, 34.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2420006086_05__1_res сохранены в result/2420006086_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2819702815_02.png: 640x576 3 28s, 1 номер, 33.0ms
# Speed: 1.9ms preprocess, 33.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2819702815_02__1_res сохранены в result/2819702815_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820720395_05.png: 640x576 1 28, 33.7ms
# Speed: 1.8ms preprocess, 33.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820720395_05__1_res сохранены в result/2820720395_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220199681_02.png: 640x576 2 номерs, 37.9ms
# Speed: 2.0ms preprocess, 37.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220199681_02__1_res сохранены в result/2220199681_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720836996_04.png: 640x576 1 24, 1 28, 39.6ms
# Speed: 2.0ms preprocess, 39.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720836996_04__1_res сохранены в result/2720836996_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1120347499_02.png: 640x576 1 28, 41.9ms
# Speed: 1.8ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1120347499_02__1_res сохранены в result/1120347499_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2819701874_02.png: 640x576 1 22, 1 28, 1 номер, 39.6ms
# Speed: 2.0ms preprocess, 39.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2819701874_02__1_res сохранены в result/2819701874_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2419979133_04.png: 640x576 3 22s, 35.5ms
# ...
# Результаты для 1120343637_06__1_res сохранены в result/1120343637_06__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220122055_02.png: 640x576 (no detections), 32.5ms
# Speed: 1.7ms preprocess, 32.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220122055_02__1_res сохранены в result/2220122055_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2719825083_05.png: 640x576 1 22, 1 номер, 31.1ms
# Speed: 1.7ms preprocess, 31.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2719825083_05__1_res сохранены в result/2719825083_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820749303_05.png: 640x576 1 24, 1 25, 1 номер, 31.8ms
# Speed: 1.7ms preprocess, 31.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820749303_05__1_res сохранены в result/2820749303_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820714602_07.png: 640x576 1 22, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820714602_07__1_res сохранены в result/2820714602_07__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220084748_02.png: 640x576 1 22, 2 24s, 2 номерs, 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220084748_02__1_res сохранены в result/2220084748_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1421951632_02.png: 640x576 1 22, 1 24, 2 номерs, 32.4ms
# Speed: 1.9ms preprocess, 32.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1421951632_02__1_res сохранены в result/1421951632_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220105918_05.png: 640x576 1 23, 30.3ms
# Speed: 1.7ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220105918_05__1_res сохранены в result/2220105918_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220233466_02.png: 640x576 1 28, 32.5ms
# Speed: 1.7ms preprocess, 32.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220233466_02__1_res сохранены в result/2220233466_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220085848_02.png: 640x576 1 22, 1 24, 3 номерs, 31.3ms
# Speed: 1.9ms preprocess, 31.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220085848_02__1_res сохранены в result/2220085848_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720833057_03.png: 640x576 1 28, 35.0ms
# Speed: 1.9ms preprocess, 35.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720833057_03__1_res сохранены в result/2720833057_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720834356_02.png: 640x576 1 24, 36.0ms
# Speed: 1.8ms preprocess, 36.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720834356_02__1_res сохранены в result/2720834356_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2719812179_03.png: 640x576 (no detections), 34.9ms
# Speed: 1.7ms preprocess, 34.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2719812179_03__1_res сохранены в result/2719812179_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1119318375_03.png: 640x576 1 22, 1 23, 31.8ms
# Speed: 1.6ms preprocess, 31.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1119318375_03__1_res сохранены в result/1119318375_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220154421_03.png: 640x576 (no detections), 32.3ms
# Speed: 1.6ms preprocess, 32.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220154421_03__1_res сохранены в result/2220154421_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820756680_06.png: 640x576 1 24, 1 25, 31.6ms
# Speed: 1.6ms preprocess, 31.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820756680_06__1_res сохранены в result/2820756680_06__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220228189_04.png: 640x576 1 28, 36.9ms
# Speed: 1.8ms preprocess, 36.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220228189_04__1_res сохранены в result/2220228189_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1119267419_04.png: 640x576 1 номер, 34.8ms
# Speed: 1.7ms preprocess, 34.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1119267419_04__1_res сохранены в result/1119267419_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820722961_04.png: 640x576 1 22, 1 номер, 32.0ms
# Speed: 1.8ms preprocess, 32.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820722961_04__1_res сохранены в result/2820722961_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720853977_06.png: 640x576 4 28s, 29.8ms
# Speed: 1.6ms preprocess, 29.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720853977_06__1_res сохранены в result/2720853977_06__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2420024624_03.png: 640x576 1 24, 33.6ms
# Speed: 1.7ms preprocess, 33.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2420024624_03__1_res сохранены в result/2420024624_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220142244_03.png: 640x576 1 28, 33.2ms
# Speed: 1.7ms preprocess, 33.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220142244_03__1_res сохранены в result/2220142244_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1120351624_02.png: 640x576 1 22, 1 23, 32.4ms
# Speed: 1.6ms preprocess, 32.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1120351624_02__1_res сохранены в result/1120351624_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2420011810_02.png: 640x576 2 22s, 1 23, 3 номерs, 35.9ms
# Speed: 1.8ms preprocess, 35.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2420011810_02__1_res сохранены в result/2420011810_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720837316_05.png: 640x576 1 28, 36.9ms
# Speed: 1.8ms preprocess, 36.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720837316_05__1_res сохранены в result/2720837316_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220166802_03.png: 640x576 (no detections), 33.7ms
# Speed: 1.7ms preprocess, 33.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220166802_03__1_res сохранены в result/2220166802_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720857994_06.png: 640x576 1 28, 30.4ms
# Speed: 1.8ms preprocess, 30.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720857994_06__1_res сохранены в result/2720857994_06__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220184268_03.png: 640x576 1 номер, 31.6ms
# Speed: 1.7ms preprocess, 31.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220184268_03__1_res сохранены в result/2220184268_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2221287176_02.png: 640x576 1 22, 2 24s, 2 номерs, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2221287176_02__1_res сохранены в result/2221287176_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220169632_05.png: 640x576 1 28, 62.2ms
# Speed: 19.4ms preprocess, 62.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220169632_05__1_res сохранены в result/2220169632_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220135069_04.png: 640x576 1 22, 1 24, 37.4ms
# Speed: 1.6ms preprocess, 37.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220135069_04__1_res сохранены в result/2220135069_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2719812559_04.png: 640x576 1 24, 34.6ms
# Speed: 1.8ms preprocess, 34.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2719812559_04__1_res сохранены в result/2719812559_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1920297439_04.png: 640x576 1 28, 31.7ms
# Speed: 1.7ms preprocess, 31.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1920297439_04__1_res сохранены в result/1920297439_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820730356_02.png: 640x576 1 22, 30.8ms
# Speed: 1.7ms preprocess, 30.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820730356_02__1_res сохранены в result/2820730356_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220143890_04.png: 640x576 1 28, 31.6ms
# Speed: 1.9ms preprocess, 31.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220143890_04__1_res сохранены в result/2220143890_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220152100_04.png: 640x576 1 22, 31.4ms
# Speed: 1.6ms preprocess, 31.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220152100_04__1_res сохранены в result/2220152100_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220217309_04.png: 640x576 2 22s, 1 24, 1 номер, 34.5ms
# Speed: 1.8ms preprocess, 34.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220217309_04__1_res сохранены в result/2220217309_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220204209_06.png: 640x576 1 27, 37.5ms
# Speed: 2.0ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220204209_06__1_res сохранены в result/2220204209_06__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1420866592_02.png: 640x576 (no detections), 38.1ms
# Speed: 1.7ms preprocess, 38.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1420866592_02__1_res сохранены в result/1420866592_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1120346087_03.png: 640x576 1 22, 1 24, 34.8ms
# Speed: 1.9ms preprocess, 34.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1120346087_03__1_res сохранены в result/1120346087_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220094308_04.png: 640x576 (no detections), 31.4ms
# Speed: 2.0ms preprocess, 31.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220094308_04__1_res сохранены в result/2220094308_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2420013527_04.png: 640x576 1 28, 2 номерs, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2420013527_04__1_res сохранены в result/2420013527_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820720456_02.png: 640x576 2 номерs, 31.4ms
# Speed: 1.7ms preprocess, 31.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820720456_02__1_res сохранены в result/2820720456_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2223670527_05.png: 640x576 1 28, 30.9ms
# Speed: 1.8ms preprocess, 30.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2223670527_05__1_res сохранены в result/2223670527_05__1_res.txt
# В 2220199996_03__1_res не найдены тексты
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1119292456_02.png: 640x576 1 номер, 32.4ms
# Speed: 1.7ms preprocess, 32.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1119292456_02__1_res сохранены в result/1119292456_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2719818519_04.png: 640x576 1 22, 1 номер, 43.6ms
# Speed: 1.8ms preprocess, 43.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2719818519_04__1_res сохранены в result/2719818519_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220145045_04.png: 640x576 3 22s, 1 24, 1 номер, 35.0ms
# Speed: 1.8ms preprocess, 35.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220145045_04__1_res сохранены в result/2220145045_04__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2720869240_06.png: 640x576 1 28, 31.9ms
# Speed: 1.8ms preprocess, 31.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2720869240_06__1_res сохранены в result/2720869240_06__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1020679752_02.png: 640x576 1 24, 3 номерs, 30.7ms
# Speed: 1.9ms preprocess, 30.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1020679752_02__1_res сохранены в result/1020679752_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2820711227_03.png: 640x576 (no detections), 29.6ms
# Speed: 1.8ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2820711227_03__1_res сохранены в result/2820711227_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2819694002_06.png: 640x576 (no detections), 34.2ms
# Speed: 1.7ms preprocess, 34.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2819694002_06__1_res сохранены в result/2819694002_06__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2419992774_02.png: 640x576 1 22, 1 номер, 33.2ms
# Speed: 1.7ms preprocess, 33.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2419992774_02__1_res сохранены в result/2419992774_02__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2220125102_05.png: 640x576 1 24, 1 номер, 51.1ms
# Speed: 1.9ms preprocess, 51.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2220125102_05__1_res сохранены в result/2220125102_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2819688928_03.png: 640x576 1 номер, 33.6ms
# Speed: 1.8ms preprocess, 33.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2819688928_03__1_res сохранены в result/2819688928_03__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/1119305077_07.png: 640x576 1 28, 31.8ms
# Speed: 1.7ms preprocess, 31.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 1119305077_07__1_res сохранены в result/1119305077_07__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2420023476_05.png: 640x576 1 22, 32.1ms
# Speed: 1.8ms preprocess, 32.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2420023476_05__1_res сохранены в result/2420023476_05__1_res.txt
#
# image 1/1 /Users/persona21/proj/OCR_test/MAI_practice/301/2719826797_04.png: 640x576 1 номер, 30.3ms
# Speed: 1.9ms preprocess, 30.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
# Результаты для 2719826797_04__1_res сохранены в result/2719826797_04__1_res.txt

# %%
print(model.names)
# Out:
# {0: '22', 1: '23', 2: '24', 3: '25', 4: '26', 5: '27', 6: '28', 7: 'номер', 8: 'текст'}
